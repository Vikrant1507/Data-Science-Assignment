# %% [markdown]
# # Question 22

# %%
from scipy import stats
from scipy.stats import norm

# %%
#Z score of 90% confidence
stats.norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
#Z score of 94% confidence
stats.norm.ppf(0.94)
# Out:
# 1.5547735945968535

# %%
#Z score of 60% confidence
stats.norm.ppf(0.60)
# Out:
# 0.2533471031357997

# %% [markdown]
# # Question 23

# %%
from scipy import stats
from scipy.stats import norm

# %%
# t score of 95% confidence #df=n-1
stats.t.ppf(0.975,24)
# Out:
# 2.0638985616280205

# %%
# t score of 96% confidence #df=n-1
stats.t.ppf(0.98,24)
# Out:
# 2.1715446760080677

# %%
# t score of 99% confidence #df=n-1
stats.t.ppf(0.995,24)
# Out:
# 2.796939504772804

# %% [markdown]
# # QUESTION 24

# %%
from scipy import stats
from scipy.stats import norm

# %%
# Assume Null Hypothesis is: Ho = Avg life of Bulb >= 260 days
# Alternate Hypothesis is: Ha = Avg life of Bulb < 260 days

# %%
# find t-scores at x=260; t=(s_mean-P_mean)/(s_SD/sqrt(n))
t=(260-270)/(90/18**0.5)
t
# Out:
# -0.4714045207910317

# %%
# Find P(X>=260) for null hypothesis

# %%
# p_value=1-stats.t.cdf(abs(t_scores),df=n-1)... Using cdf function
p_value=1-stats.t.cdf(abs(-0.4714),df=17)
p_value
# Out:
# 0.32167411684460556

# %%
#  OR p_value=stats.t.sf(abs(t_score),df=n-1)... Using sf function
p_value=stats.t.sf(abs(-0.4714),df=17)
p_value
# Out:
# 0.32167411684460556
